# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('dataset.csv')

# %%
ds = ds.replace('ND', np.nan)

# %%
ds = ds.fillna(method ='pad')

# %%
ds=ds.drop('Unnamed: 0',axis=1)

# %%
columns = list(ds)

# %%
columns
# Out:
# ['Time Serie',
#  'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
#  'EURO AREA - EURO/US$',
#  'NEW ZEALAND - NEW ZELAND DOLLAR/US$',
#  'UNITED KINGDOM - UNITED KINGDOM POUND/US$',
#  'BRAZIL - REAL/US$',
#  'CANADA - CANADIAN DOLLAR/US$',
#  'CHINA - YUAN/US$',
#  'HONG KONG - HONG KONG DOLLAR/US$',
#  'INDIA - INDIAN RUPEE/US$',
#  'KOREA - WON/US$',
#  'MEXICO - MEXICAN PESO/US$',
#  'SOUTH AFRICA - RAND/US$',
#  'SINGAPORE - SINGAPORE DOLLAR/US$',
#  'DENMARK - DANISH KRONE/US$',
#  'JAPAN - YEN/US$',
#  'MALAYSIA - RINGGIT/US$',
#  'NORWAY - NORWEGIAN KRONE/US$',
#  'SWEDEN - KRONA/US$',
#  'SRI LANKA - SRI LANKAN RUPEE/US$',
#  'SWITZERLAND - FRANC/US$',
#  'TAIWAN - NEW TAIWAN DOLLAR/US$',
#  'THAILAND - BAHT/US$']

# %%
ds[columns[1:]] = ds[columns[1:]].apply(pd.to_numeric)

# %%
ds['Time Serie']=pd.to_datetime(ds['Time Serie'])

# %%
x = ds['Time Serie']
y = ds['SOUTH AFRICA - RAND/US$']

# %%
plt.plot(x, y)
# Out:
# C:\Users\daddy\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
x = ds['Time Serie']
y = ds['SINGAPORE - SINGAPORE DOLLAR/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['DENMARK - DANISH KRONE/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['JAPAN - YEN/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['MALAYSIA - RINGGIT/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['NORWAY - NORWEGIAN KRONE/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['SWEDEN - KRONA/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['SRI LANKA - SRI LANKAN RUPEE/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['SWITZERLAND - FRANC/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['TAIWAN - NEW TAIWAN DOLLAR/US$']

plt.plot(x, y)

# %%
x = ds['Time Serie']
y = ds['THAILAND - BAHT/US$']

plt.plot(x, y)

# %%
import geopandas as gpd

# %%
fp = "99bfd9e7-bb42-4728-87b5-07f8c8ac631c2020328-1-1vef4ev.lu5nk.shp"
map_df = gpd.read_file(fp)
map_df.head()
# Out:
#    OBJECTID           CNTRY_NAME  \
# 0         1                Aruba
# 1         2  Antigua and Barbuda
# 2         3          Afghanistan
# 3         4              Algeria
# 4         5           Azerbaijan
#
#                                             geometry
# 0  POLYGON ((-69.88223 12.41111, -69.94695 12.436...
# 1  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2  POLYGON ((61.27656 35.60725, 61.29638 35.62853...
# 3  POLYGON ((-5.15213 30.18047, -5.13917 30.19236...
# 4  MULTIPOLYGON (((45.02583 41.03055, 45.00999 41...

# %%
f_new = "TM_WORLD_BORDERS-0.3.shp"
map_df_new = gpd.read_file(f_new)
map_df_new.head()
# Out:
#   FIPS ISO2 ISO3  UN                 NAME    AREA   POP2005  REGION  \
# 0   AC   AG  ATG  28  Antigua and Barbuda      44     83039      19
# 1   AG   DZ  DZA  12              Algeria  238174  32854159       2
# 2   AJ   AZ  AZE  31           Azerbaijan    8260   8352021     142
# 3   AL   AL  ALB   8              Albania    2740   3153731     150
# 4   AM   AM  ARM  51              Armenia    2820   3017661     142
#
#    SUBREGION     LON     LAT  \
# 0         29 -61.783  17.078
# 1         15   2.632  28.163
# 2        145  47.395  40.430
# 3         39  20.068  41.143
# 4        145  44.563  40.534
#
#                                             geometry
# 0  MULTIPOLYGON (((-61.68667 17.02444, -61.73806 ...
# 1  POLYGON ((2.96361 36.80222, 2.98139 36.80694, ...
# 2  MULTIPOLYGON (((45.08332 39.76804, 45.26639 39...
# 3  POLYGON ((19.43621 41.02107, 19.45055 41.06000...
# 4  MULTIPOLYGON (((45.57305 40.63249, 45.52888 40...

# %%
map_df = map_df[['CNTRY_NAME', 'geometry']]
map_df.plot()

# %%
for i in range(12,23):
    x=ds[columns[0]]
    y=ds[columns[i]]
    plt.plot(x,y)
    plt.xlabel("Years")
    plt.ylabel("Currency Value")
    plt.title(columns[i])
    fname=columns[i].split(' ')[0]+'.jpg'
    plt.savefig(fname,dpi=500)
    plt.show()

# %%
df = ds[columns[1:]].apply(pd.to_numeric)

# %%
df = df.median(axis = 0)

# %%
country = []
for i in range(1,23):
    fname=columns[i].split(' ')[0]
    country.append(fname)

# %%
df
# Out:
# AUSTRALIA - AUSTRALIAN DOLLAR/US$               1.3115
# EURO AREA - EURO/US$                            0.8158
# NEW ZEALAND - NEW ZELAND DOLLAR/US$             1.4426
# UNITED KINGDOM - UNITED KINGDOM POUND/US$       0.6366
# BRAZIL - REAL/US$                               2.3310
# CANADA - CANADIAN DOLLAR/US$                    1.2372
# CHINA - YUAN/US$                                6.8597
# HONG KONG - HONG KONG DOLLAR/US$                7.7806
# INDIA - INDIAN RUPEE/US$                       48.1100
# KOREA - WON/US$                              1127.7900
# MEXICO - MEXICAN PESO/US$                      12.4730
# SOUTH AFRICA - RAND/US$                         8.1791
# SINGAPORE - SINGAPORE DOLLAR/US$                1.4084
# DENMARK - DANISH KRONE/US$                      6.0740
# JAPAN - YEN/US$                               109.0600
# MALAYSIA - RINGGIT/US$                          3.8000
# NORWAY - NORWEGIAN KRONE/US$                    6.7860
# ...

# %%
australia = [1.3115, ]
europe = [0.8158, 0.6366, ]
north_america = []
south_america = []
asia = []
antarctica = []
africa = []
# Out:
# ['AUSTRALIA',
#  'EURO',
#  'NEW',
#  'UNITED',
#  'BRAZIL',
#  'CANADA',
#  'CHINA',
#  'HONG',
#  'INDIA',
#  'KOREA',
#  'MEXICO',
#  'SOUTH',
#  'SINGAPORE',
#  'DENMARK',
#  'JAPAN',
#  'MALAYSIA',
#  'NORWAY',
#  'SWEDEN',
#  'SRI',
#  'SWITZERLAND',
#  'TAIWAN',
#  'THAILAND']

# %%
Russia
Ukraine
France
Spain
Sweden
Norway
Germany
Finland
Poland
Italy
United Kingdom
Romania
Belarus
Kazakhstan
Greece
Bulgaria
Iceland
Hungary
Portugal
Austria
Czechia
Serbia
Ireland
Lithuania
Latvia
Croatia
Bosnia and Herzegovina
Slovakia
Estonia
Denmark
Switzerland
Netherlands
Moldova
Belgium
Armenia
Albania
North Macedonia
Turkey
Slovenia
Montenegro
Kosovo
Cyprus
Azerbaijan
Luxembourg
Georgia
Andorra
Malta
Liechtenstein
San Marino
Monaco
Vatican City
# Out:
#   File "<ipython-input-32-7c671b023714>", line 11
#     United Kingdom
#                  ^
# SyntaxError: invalid syntax
